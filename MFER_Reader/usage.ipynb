# %%
from MFER_Reader import MFER_12Leads
import matplotlib.pyplot as plt

# %%
mfer=MFER_12Leads("2011年/000000001545_20111001104325.mwf",True)
print(mfer.datetime)
print(mfer.waveforms[0].head())
print(mfer.waveforms[1].head())
print(mfer.total_info)
print(mfer.leads_info)
print(mfer.total_events)
# Out:
# ...
# waveform 1
# 波形種別 標準１２誘導心電図
# サンプリング間隔(msec) 2.0
# サンプリング解像度(mV) 0.00125
# フィルタ情報 LPF=100 DEF=ON BEF=50^Hum filter HPF=0.04
# チャネル数 8
# ブロック長 10310
# シーケンス数 1
# ...
# waveform 2
# 波形種別 ドミナントビート抽出波形
# サンプリング間隔(msec) 2.0
# サンプリング解像度(mV) 0.00125
# フィルタ情報 No Filter
# チャネル数 8
# ブロック長 495
# シーケンス数 1
# 2011-10-01 10:43:25
#    MWF_ECG_LEAD_I  MWF_ECG_LEAD_II  MWF_ECG_LEAD_V1  MWF_ECG_LEAD_V2  \
# 0        -0.00750         -0.05500         -0.03625         -0.13625
# 1        -0.01375         -0.06125         -0.03625         -0.13625
# 2        -0.00750         -0.06625         -0.03625         -0.13625
# 3         0.00875         -0.06000         -0.03625         -0.13125
# 4         0.01250         -0.03875         -0.03625         -0.12625
#
#    MWF_ECG_LEAD_V3  MWF_ECG_LEAD_V4  MWF_ECG_LEAD_V5  MWF_ECG_LEAD_V6  \
# 0         -0.13750         -0.12750          -0.1075         -0.06750
# 1         -0.13750         -0.13375          -0.1075         -0.06750
# ...

# %%
plt.rcParams["figure.figsize"]=[20,2]
for col in mfer.waveforms[0].columns:
    print(col)
    plt.plot(mfer.waveforms[0]["offset_msec"], mfer.waveforms[0][col])
    plt.show()
# Out:
# MWF_ECG_LEAD_I
# MWF_ECG_LEAD_II
# MWF_ECG_LEAD_V1
# MWF_ECG_LEAD_V2
# MWF_ECG_LEAD_V3
# MWF_ECG_LEAD_V4
# MWF_ECG_LEAD_V5
# MWF_ECG_LEAD_V6
# MWF_ECG_LEAD_III
# MWF_ECG_LEAD_aVR
# MWF_ECG_LEAD_aVL
# MWF_ECG_LEAD_aVF
# offset_msec

# %%
plt.rcParams["figure.figsize"]=[4,2]
for col in mfer.waveforms[1].columns:
    print(col)
    plt.plot(mfer.waveforms[1]["offset_msec"], mfer.waveforms[1][col])
    plt.show()
# Out:
# MWF_ECG_LEAD_I
# MWF_ECG_LEAD_II
# MWF_ECG_LEAD_V1
# MWF_ECG_LEAD_V2
# MWF_ECG_LEAD_V3
# MWF_ECG_LEAD_V4
# MWF_ECG_LEAD_V5
# MWF_ECG_LEAD_V6
# MWF_ECG_LEAD_III
# MWF_ECG_LEAD_aVR
# MWF_ECG_LEAD_aVL
# MWF_ECG_LEAD_aVF
# offset_msec
